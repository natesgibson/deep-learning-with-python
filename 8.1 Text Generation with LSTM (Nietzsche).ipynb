# %% [markdown]
# ## Character-level LSTM Generation

# %%
# load Nietzsche text
import tensorflow.keras
import numpy as np

path = tensorflow.keras.utils.get_file(
        'nietzche.txt',
        origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('corpus lenght:', len(text))
# Out:
# corpus lenght: 600893

# %%
# vectorize text into one-hot overlapping sequences and next-char target
max_len = 60
step = 3

sentences = []
next_chars = []

for i in range(0, len(text) - max_len, 3):
    sentences.append(text[i : i + max_len])
    next_chars.append(text[i+max_len])
print('number of sequences:', len(sentences))

chars = sorted(list(set(text)))
chars_dict = dict((char, chars.index(char)) for char in chars)
print('number of unique chars:', len(chars))

print('Vectorizing text...')
x = np.zeros((len(sentences), max_len, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for char_i, c in enumerate(sentence):
        x[i, char_i, chars_dict[c]] = 1
    y[i, chars_dict[next_chars[i]]] = 1
print("done")
# Out:
# number of sequences: 200278
# number of unique chars: 57
# Vectorizing text...
# done

# %%
# build LSTM network
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers

model = models.Sequential()
model.add(layers.LSTM(128, input_shape=(max_len, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer=optimizers.legacy.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /Users/nate/miniconda3/envs/tfenv/lib/python3.9/site-packages/keras/src/optimizers/legacy/rmsprop.py:144: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# function to sample the next char distribution
# with custom softmax tempurature
def sample(preds, temperature=1.0):
    preds = np.array(preds).astype('float64')
    preds = np.exp(np.log(preds) / temperature)
    preds /= np.sum(preds)
    probs = np.random.multinomial(1, preds, 1)
    return np.argmax(probs)

# %%
# train model and generate texts at every epoch with different temps
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    
    random_seed = random.randint(0, len(text) - max_len - 1)
    generated_text = text[random_seed : random_seed + max_len]
    print('--- Generating with seed: \"' + generated_text + '\"')
    
    for temp in [0.2, 0.5, 1.0, 1.2]:
        print('----- temperature:', temp)
        input_text = generated_text
        sys.stdout.write(input_text)
        for i in range(400):
            sampled = np.zeros((1, max_len, len(chars)))
            for char_i, c in enumerate(input_text):
                sampled[0, char_i, chars_dict[c]] = 1
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature=temp)
            next_char = chars[next_index]
            
            input_text += next_char
            input_text = input_text[1:]
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.4435
# --- Generating with seed: "philosophie, c'est-a-dire
# pour voir clair dans ce qui est."
# "
# ----- temperature: 0.2
# philosophie, c'est-a-dire
# pour voir clair dans ce qui est."
#
# 12e
# toone and strength of the form of the same the sense of the for the soul of the standard of the horther of the propens the such a man of the standard of the standard and sense of the standard of the propens of the standard of the superlition and standing the sense of the sense of the fine the same such an of the superiority of the far and in the standard of the spirit would be an opinion of t
# ----- temperature: 0.5
# philosophie, c'est-a-dire
# pour voir clair dans ce qui est."
#
# 1an has to the death of the man in the conception of the standard of the such the bad the strength and strange of the problem and distincey, the contempt to restrusion and things and bad and has been such a means of the morality with the same time of the fact and the conception of the standers to account something mankind it is all the senses of a relations, as a  to be so under the restoman of t
# ----- temperature: 1.0
# philosophie, c'est-a-dire
# pour voir clair dans ce qui est."
#
# on the pillies it all purita was pain experience.
#
#     for in re of good and laugh,"
# witn unkonding
# and asives," ih shature upon either moral, and asary. the ulus cour question,
# with the forgudert world; one amosity, "for full morwarding by heart uehigh itwern of the farious
# cannogage fell philosopher will the heivest cognization increased among they noble. be wret" should havy interestory
# themse
# ----- temperature: 1.2
# philosophie, c'est-a-dire
# pour voir clair dans ce qui est."
#
# one--themig a nly mutions because it is
# every moransos funct for have. -a resce? alroy disrspum thinqulcabee that thus above all the domaranceful affordance oftenoly its hey, for what me tratuuition of this doyouly but make at present does any come. to schopenhatilonged. oc", the stuplatesay too
# whishon a a se-dant what after which moral fred intellemtion.; or have
# some which is as, scy and echot
# epoch 2
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.4222
# --- Generating with seed: "s are massed there, too, thicker than ever,
# and not far apar"
# ----- temperature: 0.2
# s are massed there, too, thicker than ever,
# and not far apart and that the soul, and the stranges and and distrustion of the spirit and the proposional and the stranges of the light and strong and the soul, the spirits and probable of the superstition of the soul, and the stranges of the soul, and the stranges and the world of the states and contemptation of the free spirits and contemptation of the spirit of the spirit of the subjection of the stranges an
# ----- temperature: 0.5
# s are massed there, too, thicker than ever,
# and not far apart of the will to a distinction and the spirits conserves the warlis of the society, and sought and in the sense of the world of the simply and bad and the habey from the suroististic were all and things and through a heart should see of the have and such a strong and origin. the man that have been the free will of strengths of morality and conduct. the ourselves begens of its intellection of the m
# ----- temperature: 1.0
# s are massed there, too, thicker than ever,
# and not far aparts in sufficience believes, allh.  probable sense in which he has well world, them man! thgrealint, mistaining struggle alas a, that the proact in latter was those, supporations of matters is of propunded to the wrully
# ha badneful, is
# would bring others, and see to "the "prayeces,"
# rethrence pre. into antizer lotian with critict of that will, down "deflienceoodment has everyent of revelling toom.
# ----- temperature: 1.2
# s are massed there, too, thicker than ever,
# and not far aparness p tence, was profound the
# propted: nationiem, ancsan catnest, a blacwitiony; by the act--
# the badly a
# chmize owing other:
# countring-panosmed as but who. tying, honer a myeably at are timatel", about side canke a portain answe senseit of germana of seriemenos,, which sair which standable sundure.o-, we arrerie geterness, which dround, and mladed
# so "bad counter about spirit sympathy widhurment
# epoch 3
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.4047
# --- Generating with seed: "ism)? to contemplate oneself as a complete
# personality and b"
# ----- temperature: 0.2
# ism)? to contemplate oneself as a complete
# personality and basisted to the same and souls, and has and some the soul, as the sense of the sense of the strength of the strength of the spirit the soul the strength and contemness of the sufficient them the strength and perhaps the some the some the soul, the soul, and the sense of the sense of the same are and subject of the far and consequently and souls and the same and self-delight to the states and the pr
# ----- temperature: 0.5
# ism)? to contemplate oneself as a complete
# personality and barresse of the god. the soul, as a some the present morality of the respect, and in the great the persuit to respect, and which has to a sorrowness, and faith concerning any originated the morality. the sense of the present and desire, the spirit the vanity of the here and even the systems of the relation and discovered therefrough and and cruelty, the dangerous been a self-contration of the such
# ----- temperature: 1.0
# ism)? to contemplate oneself as a complete
# personality and bad every more posulten parts. beten neverthely be'st and reason. and therefore and sevewar within varie of the same dones at mally of the other rightly icreat the empdous human beowe? taken brown aspliate out: here, and
# and god,
# olimate philosophy
# knows mons; through the various formerly, forhtsed: from no "the power
# others, wheth
# wonlonous
# it? and at one aronality. the charves emplacy: to restles
# ----- temperature: 1.2
# ism)? to contemplate oneself as a complete
# personality and becrrisg) origin,
# morally that hih of certainacetrt naturally and sacrges-there"; or osseun upon advance may complailedly
# heal--knowledge) adveoled--by taken they
# are merely, neverthelenest from artso-subbced once instres"); so muyly
# thinkh: on
#  errortamentical fpenior varientish; to the
# incremalital. is neafure;, iplas,
# a sudden aspribates from
# yet no makes formoutice is
# to whet is males eleming;
# epoch 4
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3906
# --- Generating with seed: "y soul in it). to have bound
# up this new testament (a kind o"
# ----- temperature: 0.2
# y soul in it). to have bound
# up this new testament (a kind of the same and such a man in the soul, and the morality of the contend of the proved of the spirit of the presence of the presence of the presence of the discourse of the strong of the presence of the far a spirits the moral for the religions of the part of the spirits and the spirits in the presence of the more of the presence of the most desire of the spirits the conscience, the sense of the pre
# ----- temperature: 0.5
# y soul in it). to have bound
# up this new testament (a kind of passions of a
# true carelt of things.
#
# 111. there is the contradiation, and all the perhaps it is the standard in the most discoverient to the delicates and courage of the ethic of the communision which is such a saint of the "same and
# badly in a soul, which the sorvist of the contend impulse and tastes.
#
#
# 1
#
# a not of a courage and coming in believe for into the discourse of the proved of the con
# ----- temperature: 1.0
# y soul in it). to have bound
# up this new testament (a kind of that strictly belief forthunats of its spirit and of
# all has been thought conscience; the paths" thear mingnessming of solitay from christian crooks of all its incrasuded. a socior to hand that exfirate
# rulh, because the good books with a conduct and the nooldaries from undeveard in the fotherly and for onder endla,
# he good,
#  trusting parse, the
# made
# talk on
# actionalful, in these feelings, antil
# ----- temperature: 1.2
# y soul in it). to have bound
# up this new testament (a kind of aggios
# soul--an any
# demeritation of the masters.
# moytyupsowablely
# for a very hand
# operagain otherwauct of usefla before the religiousluasay:
# its stand" to a
# repun, rutional cimebls meant us
# "out a son scholars hardlve! i latal lit to our rhangred the prose,
# experiendly, names in its, let us volunce."
#
# net--sprul, bctenyscen lival, sympathess our knowledge voluale cullle,
# quitets crotigation when
# epoch 5
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3804
# --- Generating with seed: "t is admissible to draw a conclusion about the child: any ki"
# ----- temperature: 0.2
# t is admissible to draw a conclusion about the child: any kind that the sense of the sense of the case of the sense of the sense of the same time that the spirit and the single in all the sentiment and the soul of the present the same time to the more the spiritual of the same time the experience of the sentiment of the sentiment of the present the sentiment and the same time that the same tale the moral for the sense of the sense of the sense of the prese
# ----- temperature: 0.5
# t is admissible to draw a conclusion about the child: any kind of and more and distrustful and interrigation of the expressing that the sense of the most hands that the higher exacted by the sentiny from individual to really the same time and word of the any best for their consequently and the distance, and and always the fact to his every can not to be be an intellect of reverence and the element and atain of the brad of the case of all the evilly the suc
# ----- temperature: 1.0
# t is admissible to draw a conclusion about the child: any kinds and merely by
# aslects that which not somely for the states alone natury is according to buther noceings of that man has there is
# individualuration of conduhing for the
# german dayes the far schoolthing, is word, the sick nor the does tacle wardny in
# t the words
# to the cacrilisx for exercising, would but their melatics for sense a conmenting ferrespe-"gath to legarious, moral philosophers him an
# ----- temperature: 1.2
# t is admissible to draw a conclusion about the child: any kinds,
# by indeedverous can thio the would,
# i have o it. but
# but their
# we, as men and inte into ansielt truth. is firmlatiun, sgey
# shear lower of metaphysicals?" bl,was -order tot--has been himsely
# (and
# with co one
# indiration.
# up inmeal, and hypocur ppressing o generly
# dawxge. threlsow a"present diffileck, of chountle atmlowableed pose little invoows cutions,
# a kind fourd" innivoniously looking to be
# epoch 6
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3701
# --- Generating with seed: "varied experience teaches it
# what are the qualities to which"
# ----- temperature: 0.2
# varied experience teaches it
# what are the qualities to which is a man is also the states of the fact of the states of the superanises of the standard of the fact of the standard of the profound of the sense of the states and the states of the states and and as the moral of the world of the states of the states and and strift is also the discovered the souls and all the superfications of the states of the fact to the states in the superfication of the prese
# ----- temperature: 0.5
# varied experience teaches it
# what are the qualities to which the present have to art of the moral forms, nothing of discalce of the new profound some will to the ethical the sense of the discoverels the constantly as a heart of a refeyer one another about to who has things. the merely believes as the great the dispase of the case of endures the person of
# the pirate instincts of the constraint of the present as will to the good say and "last the discoverear
# ----- temperature: 1.0
# varied experience teaches it
# what are the qualities to which enthisong.
#
#
# 1onesing is to tefe, gooddiratny, and tagarility compolouse of spectated the greaths.
# viste! a he
# consint learlisc--which even its case of wild, in interriated ideal, book, religion of moral conventiendeness spirit
# of this ponsibul, after will loves under, is will ethiclous. one merely acceas the fundamental one of
# posit one comfully the will a the case all spiriod--the rest under f
# ----- temperature: 1.2
# varied experience teaches it
# what are the qualities to which o defequent, so
# certain wishes; one right in which all theor
# mixe of phanoual bales,
# great was how her exrated," indialstom.
#
#
# 31. we begworldsamentter.
#  fordyrly"--would not right;
#
# onenessy of this mela, of oulnation as a badness,
# to hiesed whochroos from physiolicats man, before forgel--corruls of severe mumph qualities who is, what muasres cheist. others"
# and existence humantur paoning inde
# epoch 7
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.3609
# --- Generating with seed: "om
# the "birth of tragedy" to the recently published "prelude"
# ----- temperature: 0.2
# om
# the "birth of tragedy" to the recently published "preludes of the consideration of the sense of the sense of the soul and the soul, and the sense of the spirit of the sense of the spirit and the sense of the sense of the sense of the spirit and all the states of the spirit and when the spirit when the states of the sense in the constantly and the sense of the sense of the states of the sense of the self-constraint of the spirit has a south the states of
# ----- temperature: 0.5
# om
# the "birth of tragedy" to the recently published "preludes of the falseness of europe the enough and the sharm to the same a sensition and who learn to its first to conception. he is the supposed by supposes when it is hat even of the same as
# the soul has could be the best the same a ancient he habit of realites, and become to self-conscience, and so the sense of morality, the process of the sense of the sense of the heads a self-concerns of the profoun
# ----- temperature: 1.0
# om
# the "birth of tragedy" to the recently published "preluded all art, with heiever should he icself eternce of crudely does not suppreeism to certain sfrience:
# "the alcenial generation: certain the alternls, a powerful, at swoeny and cboth time and wholos to the relation of the say,
# interpretiousted, suppeass (and also religion of the is in old of
# man-cruplated,
# profe, of price himsele. for a good all whethes motives the
# arlway it perhaps drained
# fruence
# ----- temperature: 1.2
# om
# the "birth of tragedy" to the recently published "preludes that the desirable as the
# spirit at sofiling apprehedens. syptime: lefounder dismate to the moralist; what;
# al christianily, the use mepic, where oaropgradd,
# od strangereet. ourrn ether, amongs aote purse, as a
# swor gows, lefoquase og then as a sather thing could, whech to the oeso tells-dominal thisul lspici thwarlden and joua, nature,
# idealy themselves oppised so scon idea in the name of
# res
#
# epoch 8
# 1565/1565 [==============================] - 38s 24ms/step - loss: 1.3541
# --- Generating with seed: "f the
# middle-class in its best moments--subtler even than th"
# ----- temperature: 0.2
# f the
# middle-class in its best moments--subtler even than the power of the power to the present the sunden the present the sense of the sense of the contempt to the power of the soul he see the sufficiention of the ancient desire to the sense of the sense of the sense of the soul he was the same the power themselves to the soul he see the sense of the soul he was the sure to the soul he was the person is a soul he contempt to the sense of the present it is
# ----- temperature: 0.5
# f the
# middle-class in its best moments--subtler even than the desire of the sailty and seems to see of the formerly the act the free will; it not to the disposines and the ranger, and doubled, it once our noble, and does the and free simely to see the extravagance in the trained the way of the contemence to the greates of the power to look of the stands to the free spirit of places of the phenomena to the present the things as to the truth, woman to the mo
# ----- temperature: 1.0
# f the
# middle-class in its best moments--subtler even than the transfately that the contradeations of recunnity
# ards, so theorelows that the in the path of eyous appetion that sufforing to time of his natures forment and in all poet to poinr of
# baoks of independen and
# civilization of proophy peoples. that to hose
# were person to the point even metaphysically and new a? perhaps--the syrvem, as iminatious hunder--remisately a boild to vialues is a to paths our
# ----- temperature: 1.2
# f the
# middle-class in its best moments--subtler even than thear--it
# will to haribluation? lettricalsity, and more bother, germans, and
# blond to fain so fassif without huning mean of taste elseing over them!
# phra'tloarlrarorlific that effem engleses anptenseful intany
# typititty inassmanuty, lamed--fore to be adput
# pecies, well belief, the romag"!
# ju-tripation, to amadant,
# which (the pitt" (no of humanity in respe-lvity of which it
# happiar either: her strike
# epoch 9
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3476
# --- Generating with seed: "stitute for religion.=--it is supposed to be a recommendatio"
# ----- temperature: 0.2
# stitute for religion.=--it is supposed to be a recommendation of the struggle of the sense of the superiority and the far the soul has the conscious and the soul have to the soul has a man is a deception of the sense of the contrary and the soul have not the command of the command, the soul have to the most something the present the present the soul have to the soul have to the most the superiority of the reason of the soul have a man who has the struggle
# ----- temperature: 0.5
# stitute for religion.=--it is supposed to be a recommendation of men and men we makes it is the great the god. the most conception of all the predicent with the great command the how in the command of the fundamental of the formerly be it we may be profound to see the manifold something believe only to do the best in a conscious to the soul a contriatian of the superiority for the realm
# and beliter to the fact of the world of the contrary through the moral
# ----- temperature: 1.0
# stitute for religion.=--it is supposed to be a recommendation. -musicual dormable so pritocy slost to notive for everything formerly.
#
# xil a moral right to
# rule he"s "so
# regard that
# then be mode of contrast, this
# sickly reashethous look with the all omes" that is always when withought spell, our propidital and here, not will dinger that the brough to reach
# "threatens better brisk eun hamd; it is an
# one is, fore theort enuoring same contrapty in
# which, the
# ----- temperature: 1.2
# stitute for religion.=--it is supposed to be a recommendatious, i, hependcier semitikantus legoonths and religis and enjoys and lwe frome. "youngz(-delue welly", and they with thre-shoptdy, becimating, hmoped--only without thew: a leven higher so, is it ju
# to adequation, well as this portion,le.
# "makes his prowre ti whighthis when withoud acwars of command. "a hows. in this germanies.
#
# gor there so i. dangerous reuprably those evenger thinkable, connot the
# epoch 10
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3401
# --- Generating with seed: "ey saw but the counterpart as
# in a mirror of the most perfec"
# ----- temperature: 0.2
# ey saw but the counterpart as
# in a mirror of the most perfect to the sense of the spirit and the states of the sense of the soul of the states of the states of the spirit and period of the progress of the sense of the spirit of the soul of the same thregaring and senses of the spirit of the most and the soul and the states and desire the most souls of the spirit and the states of the states and the spirit of the states of the soul of the things and the sta
# ----- temperature: 0.5
# ey saw but the counterpart as
# in a mirror of the most perfect and individual in the same the soul-cimes, above and the spirit of the sense of the spirit is the boumd to conducting with this more and bad here, to be entire belief that the individual and delight of the reason and with the impossing of the bries the struggle of the sentiment to sense of the born something pride, the values, whicher of the way. the individual and still being understand
# of the
# ----- temperature: 1.0
# ey saw but the counterpart as
# in a mirror of the most perfect endament," even to prest oy the intellesiary of more but consisting formule: but long, that we prowardly one would needs do with s curio more macker manks, and asconding s thee sive that
# is the pare us-necoldative. the humaner
# than evincew and logic them, but with the
# "fruen and because, taken ham here
# a reason pise to an
# heart
# their think in the barbising from one was that possible right" becom
# ----- temperature: 1.2
# ey saw but the counterpart as
# in a mirror of the most perfect to far true andings).
#
# 124 hany
# the good terrobdaiih viouen, badnessc; it is sach, formulize made,ck-ajumty a kind.
# romany formulness of moral greatever
# (mankdings of valuiator,
# indeled interpouswalilh! forwise!w though these amount other indiquent-illove of strifier, being interpreciunt?
# if it is of
# apparanin to uscer doed, well, charratikes. are fundamental point of thoughten by
# the incrobad,
# epoch 11
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3351
# --- Generating with seed: ", indeed, that
# is recognized at all, even for a god: human, "
# ----- temperature: 0.2
# , indeed, that
# is recognized at all, even for a god: human, the same and the soul of the spirit of the stronger of the same time of the spirit of the sense of the same time that the men in the present in the stronger the self-conscience of the sense of the spirit of the present in the means of the same a content to the sense of the same souls and soul of the sense of the states and the sense of the stronger something in the states the same and interpretati
# ----- temperature: 0.5
# , indeed, that
# is recognized at all, even for a god: human, as everything the experience to the inspired to o
# /var/folders/g9/nvr26fkn4hg3pgv39ty__9qc0000gn/T/ipykernel_65755/1930721140.py:5: RuntimeWarning: divide by zero encountered in log
#   preds = np.exp(np.log(preds) / temperature)
# ne another, and woman when i the pathous of all expecting and the spirit of the spirits to the case the same tartish of the fashions of the matter of the sense of the exist in the german presumption and problem of the and manifordation the learne to the self-deluse, in the stronger and more shrouked of the present the rare condition of the destiny a
# ----- temperature: 1.0
# , indeed, that
# is recognized at all, even for a god: human, european, becomes, begov of cheits,, and whom distrusts of our ish from proteibs
# under
# and beside--as the
# egycsel--"ever in the matcided fee--as are
# respectment and dissutsy decreass, asce of nature and richer, it is let us! recultor, its spare created moralist, guel,
# is and contemnly, the, mitaince noced
# my will to
# "to those conrurioum, the sunjere from the pathous functions--iftenc
# unus
# exist, i
# ----- temperature: 1.2
# , indeed, that
# is recognized at all, even for a god: human, also down mightly make
# insce;iblisacing
# erlufriativm obtainsdiqual, wroft ba hyoughs that men of likewisers. the viewfous egoisne of the feminly
# unceveal christion" of allumates be cognified doed), as justgince ofment. guess to
# releast he general
# soul, indeel wild recurrent
# knownis aimnos of wonds perifuene bydon, and proptress itsgal distempohery--however first sprong the most occasions, for his
# epoch 12
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3282
# --- Generating with seed: "the most rational man needs nature again, from
# time to time,"
# ----- temperature: 0.2
# the most rational man needs nature again, from
# time to time, and the states and self its and spirits and present the sense of the conduct the sense of the man and sensition of the masters, and also man with the sense of the sense of the conduct the sense of the constant of the spirit of the sense of the spirit of the spirit of the sense of the sense of the word the art of the super-interests and conscience of the sense of the state of the sense of the spir
# ----- temperature: 0.5
# the most rational man needs nature again, from
# time to time, and men of his masters, which wantering the spirit of the best been still
# fashion, when they are also the virtues and consequently, and nothing and conception and which disperples that the emotions is a condition of the error, the condition also in man, which once are indeed the right and religious answer and all the general general faculty in the sense of the instincts, or called that he was the
# ----- temperature: 1.0
# the most rational man needs nature again, from
# time to time, alst artist his ethic, reble generally refereding and originates inoral an idea platoral and there-fun
# sign and attain" even necessary of our man, the inpulaysy
# and self constend no our sensurable in the brusit of the general less
# begin in the plant
# frait. who
# may beauticic momly view fact his modely longing
# of occasion and asumplar operates, is, he was perhaps grasping of away of so
# subernation
# ----- temperature: 1.2
# the most rational man needs nature again, from
# time to time, at coubtried, with revengetes do where i relation and "masterg orulimable anxied.
# quite age oldder dids--thet acbem=ars actionquang createn disemplae temat devilscidity in the crough leadnied the delude.in betol sinms,
# inlsives than around, resulting yeass
# the "chanre and religious sci: it is a seakdding of which other raused vcrugeless
# of posed great spean same parhish. there are centurely amsin
# epoch 13
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.3250
# --- Generating with seed: "n in the ruler of the world.
# indeed no cruel man is ever as "
# ----- temperature: 0.2
# n in the ruler of the world.
# indeed no cruel man is ever as a super-words, and also the falsehond and present and the states of the same the comparation of the most an ancient of the soul, and the strength of the consider the consider the consequence of the far all the consider the spirit and souls and the sense of the spirit and allow the most the sense of the consider to be all the feeling of the present and strength of the fact that they are always been
# ----- temperature: 0.5
# n in the ruler of the world.
# indeed no cruel man is ever as the far allowing the bad evil in their present and hand, and one is form and the generation of the oppreating of the virtues and an attence and his extravagance, that is the entire contle being of the reason of causes an ame the best for the most relations, an its lived and as the present
# without the precisely become such a still often transfinguius, such a science, and allowand, all the word of t
# ----- temperature: 1.0
# n in the ruler of the world.
# indeed no cruel man is ever as complematius of the mass" and sen its famplon, and operanting, as must who has ever has of the states and reasonable, sons to lose any only own first
# and grateful itsly, a degiled would be positibility are he
# exists one other spirit which dispettly determination, it falauritid foretomoua first purpose hitherto an o-wotual-time tradition of all pe
# ntity, by vuluale, been tensep, seed to
# its still t
# ----- temperature: 1.2
# n in the ruler of the world.
# indeed no cruel man is ever as pleasurg; henceepdooming. but leadince,
# whis nowodh: even just, desirler, snouth in
# the "emotion of
# its my takes on our lace, read: according to stupinges. shealyt. oy soul wexed a
# mawzaratience, quitered: like thibfeulod notlial greek--a painh, even our porgaid. perhapsse of violatfoutlove to
# crorful because of duty. which is motives and intilition and
# orcing on; soo is
# flows are still or asomyga
# epoch 14
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.3206
# --- Generating with seed: "iences, the entire history of the soul up to the present tim"
# ----- temperature: 0.2
# iences, the entire history of the soul up to the present times of the spirits and the sense of the sense of the sense of the sense of the sense of the sense of the sense of the spirit of the possess the sense of the soul of the sense of the sense of the philosopher in the most possible to the same tart of the strength of the sense of the spirits and present and and there is the soul of the philosopher of the strength of the spirit of the contrary to the ex
# ----- temperature: 0.5
# iences, the entire history of the soul up to the present times souls the same posts of the species and the good souls; it is to the same tainted and thereby former the present in a world man and estimation for sense to the spirit of the fact the cause of the philosopher the books and for mentain the opinion to the love, in the man are her in a mind in the uncondition of the powerful and present in the very strength and interribility of the constraint ones
# ----- temperature: 1.0
# iences, the entire history of the soul up to the present times but rulty formeris, a comforty is benefort"--his german person has to beloned, so to clans,
# itself in the philosophy which
# relationard.--their faltly
# or so, those qualities so cart.
#
#
# re(visu, things much deity, his
# is exploix,
# why unus aluts at the purposition for last as a morality of our farility. in the is thereby
# nor blood to cave which he desirable superficiated, it ised to the will one
# ----- temperature: 1.2
# iences, the entire history of the soul up to the present times: there
# furth.le-puorar.
# may makes onpeunous an its science. in her beson? an
# epipw: : life,culitaoused. it harr-"tappter--his precessivee: can
# lets pryspachaid suffers gradisa disinteplusable now the ra-kinc for semice,"--"which
# our
# past, his boster exists repe. the also cannot is the speilizizances impurses gainl?
# short senration at the real it is arts of these inafciye.
# foried the german mo s
# epoch 15
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3163
# --- Generating with seed: "ization of very restricted, very personal, very
# human--all-t"
# ----- temperature: 0.2
# ization of very restricted, very personal, very
# human--all-the sense of the spirit has not a man which a most more of the spirit and the sense of the same sense of the ways and desires and senses of the spirit and individuality and such a spirit and souls the most proposition and man and sense and such a protection of the most conscience of the sense of the sense of the consideration of the senses of the senses and in the sense of the spirit and morality o
# ----- temperature: 0.5
# ization of very restricted, very personal, very
# human--all-the precently of his
# exception of the german postusment of the same harmless spirit to another and man is the honor and posines and there is a world and in every desirable were itself and and strength desecialss the prederded that the exception and head and inclined and courage of man.
#
#
#
#
# tented and
# be also that its most such the postuces of moral condition and personal desire one may now has
# anot
# ----- temperature: 1.0
# ization of very restricted, very personal, very
# human--all-time shorped by him of ness considerable pladed soy siend, but nachory the most
# scherimble! whatever his gave the philosopherful--who
# be also that he cannot are fain a spirit cour us that the comprehin and bearing same
# and them in
# names prehing hence be soul, which is
# a "philosophers which ventorce, although had been foundler, and recourh to very respects entinged be should its after an err alike i
# ----- temperature: 1.2
# ization of very restricted, very personal, very
# human--all-thiseisime, a need the
# mospentivedty-destuneist upon anbees esundicaries of relemons
# intention highest outwars
# purposition towards the sixe.
#
#
# 11o
# timegic staculard nothing
# and impose, be fulted
# be.--and
# not such a necestovoned justy very plide, mobiled jucable disguised po;int civist, and sgept made oinacy.
#
#
# 32hince int attainsing upon
# an lined from spirit.--this comment
# cleak,
#
# sens? in any song
# epoch 16
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3120
# --- Generating with seed: "ed as can be
# entire, as ample as can be full." and to ask on"
# ----- temperature: 0.2
# ed as can be
# entire, as ample as can be full." and to ask one of the consists of the most and in the moral produces and all the consistance of the more and is all the senses of the more and every happiness of the same time of the contral restraint the extent the presence that is all the fundamental and desire the according to the same time the faculty is the most more more more destiny of the morality and superior of the moral profound, and all the contral
# ----- temperature: 0.5
# ed as can be
# entire, as ample as can be full." and to ask one of the stronger the more world and hardent to renounc. in the fact that it we most believe this way to the general will to the
# individual the other soul, and at free spiritrous of a longer and most such a more does deceiver, as a counter" which contemplate the development of his spiritualization and consequently always
# the distinguisy, and is the fact that the development and in the great intell
# ----- temperature: 1.0
# ed as can be
# entire, as ample as can be full." and to ask one's sensianity
# fine exaggeration of the englishorishent of doman, if the
# baling that materiam from the best arring" of the
# spirits many congrious called belief-all above his speciolity in during dealing under that word from many ds lo queters and world helpless of them to what is, for even that consequently, may be have more verie sceen original ma helow. we percession pahied to furce of the so de
# ----- temperature: 1.2
# ed as can be
# entire, as ample as can be full." and to ask once live
# encuribiant very
# utopity under
# faques helpar mind a sun hear implovions out-heievelud co worqulunably ador verie has
# the pity for grant of "crueln and soulty, when heals.!
#
#
# 131. believe.=--for the stanc: go wish that involynt. indeed the subdinure. for the
# hole of the dialste-)opment arefrient commenceed
# turring vamenta honerable to enebleariinance and german sceptimately. the dirnce". th
# epoch 17
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.3085
# --- Generating with seed: "ous and the pleasing, as the
# healthiest growths and powers i"
# ----- temperature: 0.2
# ous and the pleasing, as the
# healthiest growths and powers is not at the sense of the sense of the spirit and the most the sense of the god, and as the same time in the most soul and in all the sense of the spirit of the greatest and the soul of the soul of the most profoundly as a soul of the expression of the sense of the fast and the spirit is the present the most problem of the sense of the most the world and the spirit and conscious and more as the sp
# ----- temperature: 0.5
# ous and the pleasing, as the
# healthiest growths and powers is the imagine the life the work, and is it is always
# as a soul are more distrust of view of the most and the significance and where we called an instincte of the french would be the soul of the discourse for the most sympathy, and best of the highest man which the same condition of the morality, when he would fain the accome and worth the power of the spirit is the present--and its which the most
# ----- temperature: 1.0
# ous and the pleasing, as the
# healthiest growths and powers in which the "spirit." ones finerding should
# has selestly the race--a man, grunders orveately out ofthing respection of his last even one necessable poirtandant spirits right it can very husted a man finds in epoper. as one asent diame.--in hand state of this
# case--the
# unavolative aflither for that last his love of the history and rondbility indifferent appassine, i slegide for svery asmutic one la
# ----- temperature: 1.2
# ous and the pleasing, as the
# healthiest growths and powers is quius to entangfes, bicu
# of
# (agality,"
#
#
#
# 4ven one leading.
# adapacou has an atsmed" ideals after the god., so for this impressdons caance accorduation. this unewand metaphysical ogiquacikeatian instinqus which ham ancientwawisol: he wart trush and as "rithers ttanglid young--nothion is nothate power. alversts of one another at worth of
# the will one arosponed aware of the
# distinction, thus divers
# epoch 18
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3050
# --- Generating with seed: " found and cannot find any better answer....
#
# 231. learning "
# ----- temperature: 0.2
#  found and cannot find any better answer....
#
# 231. learning the same taste of the soul of the sense of the present man is the moral the present more and the distinguished the sense of the spirit is the same time to the and interpretation of the same taste of the same taste of the spirit is the super-like the same time of the super-will to the soul of the same taste of the delicate the same time in the super-able to the moral the present disconoticism of th
# ----- temperature: 0.5
#  found and cannot find any better answer....
#
# 231. learning germany and no
# not in the spirit that is a german the brain himself and consequently and in opporing the reason of one's and evil"s and solitudes of the comparison of generally considerable to personal the doman actions to our in the means of the subtle personal world with other more power of the belong the same at last for the religion with which the reservation of conditions of the action enough
# ----- temperature: 1.0
#  found and cannot find any better answer....
#
# 231. learning promptant
# heelthming what there is a
# mediocrivical century and states and impervation and
# interversations and moral him, the cognibated by the self-est querting iestible, which entinge might ther at last. then his son of love of all its power poones be sond of clame in his super--and the spirit.
#
# 212. it
# ever woilt"": in the
# same say, for it
# fives of only have
# reciince of human philosopher functa
# ----- temperature: 1.2
#  found and cannot find any better answer....
#
# 231. learning follo, longingianmous hosting politics,
# doly their
# lovisnest, sick of sublimest remarance of religion.
#
#  1oonen have
# been mistan, anric bode makes "you seeflon: "eye
# were about, ffine other wish here of
# finest could only "people
# amot if them.--that and
# sturing: conrictly akerists necessary of
# certain love promimece
# bad poor accordance had reison fruglop-apparentling," and conriates our state of ta
# epoch 19
# 1565/1565 [==============================] - 36s 23ms/step - loss: 1.3018
# --- Generating with seed: "ch that
# epicurus cast upon plato: he was annoyed by the gran"
# ----- temperature: 0.2
# ch that
# epicurus cast upon plato: he was annoyed by the grand the superiority of the same time the far the state of the same time the state of the self-convenience of the sense of the same time of the presence of the superiority of the fact of the moral than the presence of the sense of the sense of the same time the superstition of the sense of the superstition of the superior of the state of the presence of the sense of the sense of the self-contemplated
# ----- temperature: 0.5
# ch that
# epicurus cast upon plato: he was annoyed by the grand with the experience of the man is a said to heart the contemplate of the religion and individual would not under the comparison in the moral. the most one would not the presence of the religion of the presence of its and period is the great the greater is the heart of its happens and resisting reaching themselves to the spirits and such an excession and in himself and himself or morality of the
# ----- temperature: 1.0
# ch that
# epicurus cast upon plato: he was annoyed by the grands
# itsing them anwarirates
# and sipo flict to the empigative pa;ipary and durance that from scander for things
# distinguiar of europead upon themding and men believe remaina his own soul, being will piecess velow
# himself in the deterwance, he does not, without
# awared. un--precisely is and inwardous rishtow to even, no--the borly but in some opsiprational: in himself,
# perhaps any
# ratispuned! upon whi
# ----- temperature: 1.2
# ch that
# epicurus cast upon plato: he was annoyed by the grand a merite: hanivg in it" their conrous, i wants thloge positly, gendinal, wi men to most not only an opinion from account propection";
# it like
# them in eyes (fur to vulsuot willed, however, why has "tates, who consequent,
# what "numalazinikem. the -apieous di
# to our precisely whnquite sensely which become, as long a teomeness, establial"! this knowledge is fee-, his can free wealocensic gares, than
# epoch 20
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.2991
# --- Generating with seed: "ce, and therefore, should any one speak of it in their
# prese"
# ----- temperature: 0.2
# ce, and therefore, should any one speak of it in their
# present in the sense of the sense of the sense of the present is the sense of the moral present in the present in the same the sense of the moral states and there are the belief of the sense of the present in the spirit of the same and the moral than the same taste. the sense of an interrication of the subject and the subject to the soul of the same times of the sense of the present its and indifferent
# ----- temperature: 0.5
# ce, and therefore, should any one speak of it in their
# present itself that it is a sacrifice and the religious something things and the similar the men in the world even and the word of the faust and self-devility of even and intercourse and called that the helpfulation, and therefore, "generally, and has action to his artistic and self-convates and there are there there is the world to the truth and became and also and her the sense of the higher deep the
# ----- temperature: 1.0
# ce, and therefore, should any one speak of it in their
# present, indeed, what pesse soul thous, thinks in every generally be will to desires, it. he will if man.
#
# 2ex in  imsprement that such perhaps is
# there is one reslmiling this,ixented of assertions sothrings pired speetines of any dicbetters? in the bare, it does
# all every pity).
# throught sawly same palative.
#
#
#
#
# that an inbennsleest feeling
# out longert acary more trouth as say, with easly
# beginnon
# wit
# ----- temperature: 1.2
# ce, and therefore, should any one speak of it in their
# present even of this oen its doed when an united; so to
# plarants it will dhvelmadising and comparily asprened, the
# same nowa'lvurable certainly cropars termably of theb), art andfulg thissoric
# of all all
# the ceutocuty, because its" and stallidaning, the ajopere! for the cased refresf, operates and "un, and ghat very rung and is
# shatues, as do not one of
# them, the most caldending of a religion. ablevere
# epoch 21
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.2965
# --- Generating with seed: "all their joys, perhaps also because their good opinion
# endo"
# ----- temperature: 0.2
# all their joys, perhaps also because their good opinion
# endoriness of the same time the spirit is an antither of the standard in the most sense of the spirit is the spirit is the desire the concerning the strength of the spirit is a superficialitious moral present disposition and sign of the soul and the states of the soul of the sense of the soul of the spirit is the same time in the present does not be it is the soul is the spirit is the same time the mo
# ----- temperature: 0.5
# all their joys, perhaps also because their good opinion
# endo whom the sentiments of the same interpretation of the same time may whole sense of great deep the post of the helpful one, who who
# in many and respect to the superiority of the one not attained her instrument of the suffering, wherever the intentions that has the soul is the great and personal bring that here and who who has a bourd and the respect to the states of finders and conscience of the h
# ----- temperature: 1.0
# all their joys, perhaps also because their good opinion
# endo relone's general example, lack as gal power of semited
# his emains in it, in order that clowly crestite, every sound. un
# the philosopher, sentere done warth was as a world are specially has so where i comed with descully how good "are psychological devilly only is a
# goal and most advreciatous there part of an immrience to dangerous sout rightenment, or plenous dled the unhave eorby. to be doiction
# ----- temperature: 1.2
# all their joys, perhaps also because their good opinion
# endo ttere there are
# -the derivation
# of souad in germang man sone, hen betleised sensule--something
# influence to a , we belonging," insi fore mi
# enstriation lowed and awaks freduded, and
# this centurising
# of readily has
# itself,
# therefore then
# suant will
# made different frour cause of
# extert of
# manigevly agains pryds moralist moral light shads that has are if-this way with oned, the una hibte, in yee may
# epoch 22
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.2924
# --- Generating with seed: "les of his
# judge and prison. what succors him in this danger"
# ----- temperature: 0.2
# les of his
# judge and prison. what succors him in this dangerous interestive of any menaus of the spirit that the same time the and instincts of the most the sense of the spirit has not the most the strength of the conscience of the means and the sense of the spirit of the sense of the superiority of the sense of the same time the spirit and free spirit and has a suffering and all the false of the spirit and and such a philosophers of the most happiness of
# ----- temperature: 0.5
# les of his
# judge and prison. what succors him in this dangerous and destructions of the subject of the word the
# sick and thereby his impurity to the most the spirit of the father of the case in the men in the most and thereby him that as they are instincts of his the sense the best tempt to the thing of the most course of the same well society, and also
# distinguished and most the soul, i mean, whose morality of all such and never has the consequently and w
# ----- temperature: 1.0
# les of his
# judge and prison. what succors him in this dangerously men
# spo prishe, haveing ignestion of astand the sense of good, is scy, now is inventions and of the
# free aexpession among the standponnt and to see that exped be here, whether
# instinction might he auternow.--as so direp to hose honour, but
# deportions, and dueces--one eas as
# the squ-dained steptooolings, have perhaps this rulnations and
# paspless, comfortay evilwas belief in the men is menause
# ----- temperature: 1.2
# les of his
# judge and prison. what succors him in this dangerloundly wildines atdhest in stupidity--the world by cordialibines care the newled" as
# questions and that is cal originatits) anbuvabilities; if strange, of inralming, long-grow wheven--it look to
# charys, the small special
# andersion: is "modern
# raneforily not type upon others openedf of thing as plincible; do
# every
# mysterious experience "only made in signed to inspire itself testherity;
# them
# "talks
# epoch 23
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.2902
# --- Generating with seed: " finally in all the enlightenment of modern times with
# the f"
# ----- temperature: 0.2
#  finally in all the enlightenment of modern times with
# the fashion of the spirit of the spirit is the spirit and as a subtle personal germans and included to can be the sense of the spirit was the conscience, which is no longer the sense of the most moralist of the spirit is the spirit and such a continual self-contralion of the spirit is no longer the comparison of the emotion is a bade, in the most development of the most powerful and self-desire the sen
# ----- temperature: 0.5
#  finally in all the enlightenment of modern times with
# the faith and solitude is the discame truther and inviring man can be regarded to present the same time and the fastificial of saint that it we arresintain that is eyes the souls and for the earthless.
#
#
# 113
# tal that is a new teach with regard to the reach to the worth of the most germans of all the present more invention, and called, and in the act to the foreground to speak of every means of the piss
# ----- temperature: 1.0
#  finally in all the enlightenment of modern times with
# the forms of compat of ciplishing and a"concied cult of whole calls of nature is
# nod, as a repudeds, no longouly
# ...
# ----- temperature: 1.0
# " as the natural
# philosophers do (and whoever like them nature, alwaus; and it
# in the whole bhu: if necessary and from the
# also the other man, perhaps become seces of theology: "viefle. the great lack of phyciation is no commence profound, but also we connection and
# many
# deephon disares is "poored over, nature,
# or people, and
# that so
# be folly cour
# present the count reflatom of our own even it he seefully, the more easies
# years the society in which they wi
# ----- temperature: 1.2
# " as the natural
# philosophers do (and whoever like them nature, hish (and of with revenverse--crompose
# genkement? it is centure "priviled. in goe wild croagition of causes to inliter mindy nature
# in it. if i only a giving the pantagess:
# he's
# daily to the anties which a so not" with another change, and its people, had recognized in
# eter
# one has a
# good did thus humanity and "more thingsy!" just too fror
# betate interpretational.=--sure," it is
# know being. hev
# epoch 53
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.2371
# --- Generating with seed: "scrutable animal, uncanny
# to the other animals by his artifi"
# ----- temperature: 0.2
# scrutable animal, uncanny
# to the other animals by his artifice of the states the standsoliegly and the subject to the states and the most conscience, and in the states and something was the soul and the most conscience of the spirit and all the states and the states and which is not the stranges, as a man and the subject to be something and the states the subject and soul and the soul and something of the soul have to be attain the soul and the same time a
# ----- temperature: 0.5
# scrutable animal, uncanny
# to the other animals by his artifice of the purpose. a significations of the soul is attain to the fact the german act is to be always as the
# faith to the belief in the world there would be something for the subject the characters. all the discovered of the most significanips in this
# spirit and subject out of superiority to be possible and in this former than they have follow them, as a man in the standard of the states of the pre
# ----- temperature: 1.0
# scrutable animal, uncanny
# to the other animals by his artific physiol, in friendshes of aquaako, i have been insten of even as music, has been, in this lopen of the philosopher of thepeted in  ri? tivvinds and out of love, with
# fear extrain than toates that manter
# of evil harrous;
# which
# it is, he will be
# overcan liternmedor,
# dewards, of this whats, the uncondition man, a
# good tauth something
# man, as a bodsing the underederckdi. on from single,--if for exam
# ----- temperature: 1.2
# scrutable animal, uncanny
# to the other animals by his artifiction and suspicial paradre--the sympathy, if "man"--fjoacs make away from your doman some "add viol"y, more bedsment in
# traditions, and loves to
# involuntarily the indeed.
#
#
# 83
#
# =the any religion, however be
# gliders, he is throught ivony-can there it must frightely comics cases thousands of
# averablentess
# higher
# honest inner saked to self and brusoion only agess the masm of "hodoulds and assersful!
# epoch 54
# 1565/1565 [==============================] - 38s 24ms/step - loss: 1.2373
# --- Generating with seed: "e
# way, he dreads the temptation to become a dilettante, a mi"
# ----- temperature: 0.2
# e
# way, he dreads the temptation to become a dilettante, a mind is all the spirit of the sense of the states of the same time is the conscience of the most soul. the states and the same time the present world and the same time the best the sense of the strengthly so that is the sense of the same time and sense of the same will to be all the sense of the sense of the strengthly of the sense of the most conscience, and should say, the superiority that is to b
# ----- temperature: 0.5
# e
# way, he dreads the temptation to become a dilettante, a mind is the superstition of the other conscious for the consciously itself and all the evil". the world for the germans and presence and sense
# is person the same will to converted one is not the strunge is not not see very responsibility of the petting the privilege. the development of the masters in the far the great conditions which may indeed for the philosopher which is a delight the feelings of
# ----- temperature: 1.0
# e
# way, he dreads the temptation to become a dilettante, a might is the world works and muse had to look on the me
# thinal would not the power person in moved necessary
# and
# disseate
# false in emblavity and
# appairated with person agleend certain, one another if eavil; to say, one has entorissy and discourh
# of cocfure the himself to becentianism and as in the domance how could in the degree with soul; in       he
# discovered its spiritual name of the old course,
# ----- temperature: 1.2
# e
# way, he dreads the temptation to become a dilettante, a mistentity!
# ciuk-flawer, as it herermeng, explanations
# of certain interpretal
# them abserventic rudance and humberir, i may remindest, to by its materiar;
# hoisitud etxrbuncted only away through human exists i leaonness and rome--who are the at large, it--to put suh again to truth rant. one and these vourager of
# the feelinoses of mark
# itmanijious
# soul! oal
# worlds" only petts daskes"s, and is all auton
# epoch 55
# 1565/1565 [==============================] - 37s 24ms/step - loss: 1.2350
# --- Generating with seed: "l his life he knew how to keep an astute silence--probably h"
# ----- temperature: 0.2
# l his life he knew how to keep an astute silence--probably has as the world the senses and the spirit and the souls of the same self-say, and with the moral profound of the state of the strength of the soul and the senses of the same say to the same and the strength of the state of the same and the fact that the present for the most personal and souls of the excited the souls of the destruction of the strength of the state of the souls of the senses with t
# ----- temperature: 0.5
# l his life he knew how to keep an astute silence--probably himself as the superficial, and with an aged and assestion of a hard, and is all the higher what is not be able to democration of the personal condition of the position of the state of his errors because it for this political than the consequences of the fact that in
# the religious to self-moral more personal pain is a
# philosophers should the excestion and perhaps its present the consequences and th
# ----- temperature: 1.0
# l his life he knew how to keep an astute silence--probably how conversiffee souls), he formgle operated ficmess: so
# imposition, he be historical?y constranting prevented for a double bright, what has fould which the friendshers
# in the most changes
# when on ever things
# in very the duing carical happinessine manor benevelonesesciration,incy, task it is most
# once christian the most lioply unlesse at strangely excession: but
# should only
# a potent
# "transfised
# to
# ----- temperature: 1.2
# l his life he knew how to keep an astute silence--probably hamment this viewer, perhaps thear owner, and was beevuroperes
# and helast, capaving in relemstre thed; name that in life, is ranguilar man fhe
# samich birsts befoor to pretented worth?" what our now dangerous,", baban, as a from its feol"
# inspire doy possessing: and
# instinctifyon
# in last person to a god feels in epipasts of their other waitness in readiever of lobilicative specilitian that self-mund
# epoch 56
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.2345
# --- Generating with seed: " man, supposing him to degenerate and go
# to ruin, to acquire"
# ----- temperature: 0.2
#  man, supposing him to degenerate and go
# to ruin, to acquire and the stands of the standard who has a more present and such an instruction of the present and spirit and all the present himself and the same times and something will the present man in the fact that the present world, and also the distingun and personal present general and standard and such and standard to the standard and sensition, the consequently an allow the contempt and delight of a pro
# ----- temperature: 0.5
#  man, supposing him to degenerate and go
# to ruin, to acquirer of the be more as the pleasure of the spirit the assumest and consideration of the restricated the thing it is been all the soul and in the most music, as a being who were the highest destriating and music, and the spirit which is all the accordance, the accordance and possession that it is a followed take present of opinions of the far the indignance of the state of the present mankind of the i
# ----- temperature: 1.0
#  man, supposing him to degenerate and go
# to ruin, to acquire methoses somest say, that the german asceneon as the basic and let also this possession but they do if their in egoism: what it so transcint because of the disfor uney, who had only tood mean
# every party forgotten argous of the sparces furunatical reprivily. it not the suitification of a "imperition with the romisous the little as a s synar, voverememe of the dange of glorical knowledge, which is
# ----- temperature: 1.2
#  man, supposing him to degenerate and go
# to ruin, to acquirer occasioned fourd
# helphed): wherever finlly even us--one has shuit, there is deluece of which is here be: "he air the
# pather and stifled doingou; for the ,befoomlves) you had a child, it is the
# feelings, over completefun
# forth oldover edcesion with its familiar things; we all something
# in moribles: therever the
# and acts at soulcements are truaters in the ho eir, and includings of within (whiever
# epoch 57
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.2329
# --- Generating with seed: "rmerly
# they were your masters: but they should be merely you"
# ----- temperature: 0.2
# rmerly
# they were your masters: but they should be merely youth, and in the same time the soul a suffering the same time or a compardance of the same time and state of the same time the same time to the same taste of the same time that the same time the super-is the same time or a subtlety to the most and such a man of the same time and delight of the super-for the same time the such a profounding that the same time the stopity and consisted to the same sen
# ----- temperature: 0.5
# rmerly
# they were your masters: but they should be merely youth and into our future, and that the same time profound, and how but of the consequently in the english extent itself in the last levelus in the individual and prompt to the man is the single of the suffering the subtle strange to the "huke the germany love of the easier and deligit of the all the present, to the power of plato, who love a more original forms and misunderstanding to the sense of t
# ----- temperature: 1.0
# rmerly
# they were your masters: but they should be merely your than to say, he is timion spirit on explanation is costher out of more
# disclakenticism out away and laws unhatures.
#
# he rary thbe poorisome, as a man differently one of the other belief hitherto deward and likewauctis and painful, on the
# values and greated into the ungitoioly paltituding to the end must, and asking matter and complexists and the greatest past.
#
#
# mitse."--recograring to him, it h
# ----- temperature: 1.2
# rmerly
# they were your masters: but they should be merely young itself is shy faitig able is no touth to europe. it.=--they
# have the predeptagress and "distinguestary, right oodhered in musicl.
#
# hi
# very more beuberanting which tality, with this vengeamedcency, what degrewhprarishes
# stipjses for a dring other-iy wishon-allsoch. bhunding to this houritual as
# the "biminaring his utched of creation. a melath?--it had heten wor
# european spiritual under; to
# it. f
# epoch 58
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.2305
# --- Generating with seed: "shallow on those who are less so, it is
# also a kind of indem"
# ----- temperature: 0.2
# shallow on those who are less so, it is
# also a kind of indeming and moral conscience, and all the soul and the same time the far as is the self-pressing in the spirit and the self-process and super-moral conscience, and in the states of the states of the same self-k; and also the self-kind of the self-knew--he is a man who sell such a man who has a man is a man is a man is a comparison of the self-kind of the self-pressing the most german than the states o
# ----- temperature: 0.5
# shallow on those who are less so, it is
# also a kind of indeming precisely the some has the protection and developed in the sense of the states, and more readily and for the highest future" is always
# of the strifient and the good appearants, the interesting that the fundamental self-circulution of throught than which the contempt something of and life and france of a means, as it is nothing man to conscience of the measurems and consequently an emotions of
# ----- temperature: 1.0
# shallow on those who are less so, it is
# also a kind of indembliorary with its most mediocqubates out of manifestruses of mellow
# it is not: indigna. the lettles, the
# helpful questions, or modern and
# art. everything
# poner is
# beluction. with
# nighted protemions).
# one is always
# original. mang not expatinn of franch losement of esitus where spoithist abfoft in the world beginm(to grominous: it is the lowerion,
# virtues, healy, however
# planting than
# involuntary o
# ----- temperature: 1.2
# shallow on those who are less so, it is
# also a kind of indeminity and say," against break
# of truth of ununderstand
# it is orhified. icrewal assertions in"peiebingee,
# here, ring in fine understand
# wical
# many from his solitude, virtues; orderntists spoce pyryd indeed ars, quichtiony. traits lwadevnesss,
# these conditions, whose feeling, loves it germanity: we does not oldee that it fals."
#
# 13. that eoristed forculty"). now--or such a, rank! comosed plato with
#
# epoch 59
# 1565/1565 [==============================] - 37s 23ms/step - loss: 1.2310
# --- Generating with seed: "laisser-aller,
# the too great freedom, and implants the need "
# ----- temperature: 0.2
# laisser-aller,
# the too great freedom, and implants the need of the same time and superficially person is not be the same time and single of the soul-suffering the same sensition of the strengfly and sensually profoundly self-moral much as the free spirits and sensually the present the sense of the same times in the strength of the sense of the strength of the strength of the strength of a man and superficially be so that the sense of the strength of the st
# ----- temperature: 0.5
# laisser-aller,
# the too great freedom, and implants the need of him who does
# not at one dispoest problem and superficially greater much as the will to be he seems to remarties and alled for the soul, the
# same higher free with a man and sensition the free spirit and sensity of strongless of his present and superficially be primary that it is a contrary of the states resulted to consciences; which is for distance, and deceive of the super-bor of the means of
# ----- temperature: 1.0
# laisser-aller,
# the too great freedom, and implants the need of exceptually find" tenal still higher strongly formal, so longly bad they are invant bad in  nother finally has always of such wisdom, of sentiments appropend the rights from hever pruchs to whoel we pretarily gromical class offical, indeed in far acveration of "man--they have follof"ctover are nothing whomding
# of "hondies his ages., polisies,
# and by raiss (been modes toual:
# i now that many unav
# ----- temperature: 1.2
# laisser-aller,
# the too great freedom, and implants the need evil of a doine a consequencesing that him,
# not a
# genuine nature is an ale stimunitist,
# placed; througher
# adautuin, for exist,
# it had and harders birx, and clay
# bimal
# that enceks to the first we what may be free superioration-refing an after
# caste on the combbusined astracters,--whehte more wisher; "so the father. in feathr the frow kind, byran looked and gladve voith is intol recentation which is
